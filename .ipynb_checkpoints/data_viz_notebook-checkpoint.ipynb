# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.plotly as py
import plotly.graph_objs as go
from pandas.tools.plotting import scatter_matrix

# %% [markdown]
# ## Read the crime data and Exploratory Data Analysis

# %%
df = pd.read_csv('crime.csv')

# %%
df
# Out:
#                    State  Murder  Rape  Robbery  Aggravated Assault  Burglary  \
# 0                Alabama     8.2  34.3    141.4               247.8     953.8
# 1                 Alaska     4.8  81.1     80.9               465.1     622.5
# 2                Arizona     7.5  33.8    144.4               327.4     948.4
# 3               Arkansas     6.7  42.9     91.1               386.8    1084.6
# 4             California     6.9  26.0    176.1               317.3     693.3
# 5               Colorado     3.7  43.4     84.6               264.7     744.8
# 6            Connecticut     2.9  20.0    113.0               138.6     437.1
# 7               Delaware     4.4  44.7    154.8               428.2     688.9
# 8   District of Columbia    35.4  30.2    672.1               721.3     649.7
# 9                Florida     5.0  37.1    169.4               496.6     926.3
# 10               Georgia     6.2  23.6    154.8               264.3     931.0
# 11                Hawaii     1.9  26.9     78.5               147.8     767.9
# 12                 Idaho     2.4  40.4     18.6               195.4     564.4
# 13              Illinois     6.0  33.7    181.7               330.2     606.9
# 14               Indiana     5.7  29.6    108.6               179.9     697.6
# 15                  Iowa     1.3  27.9     38.9               223.3     606.4
# 16                Kansas     3.7  38.4     65.3               280.0     689.2
# 17              Kentucky     4.6  34.0     88.4               139.8     634.0
# 18             Louisiana     9.9  31.4    118.0               435.1     870.6
# 19                 Maine     1.4  24.7     24.4                61.7     478.5
# 20              Maryland     9.9  22.6    256.7               413.8     641.4
# 21         Massachusetts     2.7  27.1    119.0               308.1     541.1
# 22              Michigan     6.1  51.3    131.8               362.9     696.8
# 23             Minnesota     2.2  44.0     92.0               158.7     578.9
# 24           Mississippi     7.3  39.3     82.3               149.4     919.7
# 25              Missouri     6.9  28.0    124.1               366.4     738.3
# 26               Montana     1.9  32.2     18.9               228.5     389.2
# 27              Nebraska     2.5  32.9     59.1               192.5     532.4
# 28                Nevada     8.5  42.1    194.7               361.5     972.4
# 29         New Hampshire     1.4  30.9     27.4                72.3     317.0
# 30            New Jersey     4.8  13.9    151.6               184.4     447.1
# 31            New Mexico     7.4  54.1     98.7               541.9    1093.9
# 32              New York     4.5  18.9    182.7               239.7     353.3
# 33        North Carolina     6.7  26.5    145.5               289.4    1201.1
# 34          North Dakota     1.1  24.2      7.4                65.5     311.9
# 35                  Ohio     5.1  39.8    163.1               143.4     872.8
# 36              Oklahoma     5.3  41.7     91.0               370.5    1006.0
# 37                Oregon     2.2  34.8     68.1               181.8     758.6
# 38          Pennsylvania     6.1  28.9    154.6               235.0     451.6
# 39          Rhode Island     3.2  29.8     72.1               146.1     494.2
# 40        South Carolina     7.4  42.5    132.1               579.0    1000.9
# 41          South Dakota     2.3  46.7     18.6               108.1     324.4
# 42             Tennessee     7.2  36.4    167.3               541.9    1026.9
# 43                 Texas     6.2  37.2    156.6               329.8     961.6
# 44                  Utah     2.3  37.3     44.3               143.4     606.2
# 45               Vermont     1.3  23.3     11.7                83.5     491.8
# 46              Virginia     6.1  22.7     99.2               154.8     392.1
# 47            Washington     3.3  44.7     92.1               205.8     959.7
# 48         West Virginia     4.4  17.7     44.6               206.1     621.2
# 49             Wisconsin     3.5  20.6     82.2               135.2     440.8
# 50               Wyoming     2.7  24.0     15.3               188.1     476.3
#
#     Larceny Theft  Motor Vehicle Theft
# 0          2650.0                288.3
# 1          2599.1                391.0
# 2          2965.2                924.4
# 3          2711.2                262.1
# 4          1916.5                712.8
# 5          2735.2                559.5
# 6          1824.1                296.8
# 7          2144.0                278.5
# 8          2694.9               1402.3
# 9          2658.3                423.3
# 10         2751.1                490.2
# 11         3308.4                716.4
# 12         1931.7                201.8
# 13         2164.8                308.6
# 14         2412.0                346.7
# 15         2042.7                184.6
# 16         2758.1                339.6
# 17         1685.8                210.8
# 18         2494.5                318.1
# 19         1832.6                102.0
# 20         2294.3                608.4
# 21         1527.4                295.1
# 22         1917.8                476.5
# 23         2226.9                278.2
# 24         2083.9                256.5
# 25         2746.2                443.1
# 26         2543.0                210.7
# 27         2574.3                316.5
# 28         2153.9               1115.2
# 29         1377.3                102.1
# 30         1568.4                317.5
# 31         2639.9                414.5
# 32         1569.6                185.6
# 33         2546.2                327.8
# 34         1500.3                166.0
# 35         2429.0                360.9
# 36         2644.2                391.8
# 37         3112.2                529.0
# 38         1729.1                236.5
# 39         1816.0                408.7
# 40         2954.1                384.4
# 41         1343.7                108.4
# 42         2828.1                420.6
# 43         2961.7                408.7
# 44         2918.8                343.9
# 45         1686.1                102.9
# 46         2035.0                211.1
# 47         3149.5                783.9
# 48         1794.0                210.0
# 49         1992.8                226.6
# 50         2533.9                145.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
# State                  51 non-null object
# Murder                 51 non-null float64
# Rape                   51 non-null float64
# Robbery                51 non-null float64
# Aggravated Assault     51 non-null float64
# Burglary               51 non-null float64
# Larceny Theft          51 non-null float64
# Motor Vehicle Theft    51 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#           Murder       Rape     Robbery  Aggravated Assault     Burglary  \
# count  51.000000  51.000000   51.000000           51.000000    51.000000
# mean    5.315686  33.729412  113.917647          269.388235   690.500000
# std     4.893971  11.276725   97.856147          146.327989   233.766624
# min     1.100000  13.900000    7.400000           61.700000   311.900000
# 25%     2.600000  26.250000   66.700000          152.100000   493.000000
# 50%     4.800000  32.900000   98.700000          235.000000   649.700000
# 75%     6.700000  40.100000  153.100000          362.200000   923.000000
# max    35.400000  81.100000  672.100000          721.300000  1201.100000
#
#        Larceny Theft  Motor Vehicle Theft
# count      51.000000            51.000000
# mean     2303.486275           383.215686
# std       514.729998           252.037659
# min      1343.700000           102.000000
# 25%      1874.550000           218.850000
# 50%      2412.000000           318.100000
# 75%      2703.050000           421.950000
# max      3308.400000          1402.300000

# %% [markdown]
# Which states have the highest/lowest rate of each of the seven crimes?

# %%
max_c=df[df.columns[1:]].idxmax()
zip(max_c.index, df.ix[max_c].State)
# Out:
# Murder                  8
# Rape                    1
# Robbery                 8
# Aggravated Assault      8
# Burglary               33
# Larceny Theft          11
# Motor Vehicle Theft     8
# dtype: int64
# [('Murder', 'District of Columbia'),
#  ('Rape', 'Alaska'),
#  ('Robbery', 'District of Columbia'),
#  ('Aggravated Assault', 'District of Columbia'),
#  ('Burglary', 'North Carolina'),
#  ('Larceny Theft', 'Hawaii'),
#  ('Motor Vehicle Theft', 'District of Columbia')]

# %%
min_c = df[df.columns[1:]].idxmin()
zip(min_c.index, df.ix[min_c].State)
# Out:
# [('Murder', 'North Dakota'),
#  ('Rape', 'New Jersey'),
#  ('Robbery', 'North Dakota'),
#  ('Aggravated Assault', 'Maine'),
#  ('Burglary', 'North Dakota'),
#  ('Larceny Theft', 'South Dakota'),
#  ('Motor Vehicle Theft', 'Maine')]

# %% [markdown]
# Check correlations of crime rates accross states

# %%
#plt.figure(figsize=(10,8))
scatter_matrix(df, figsize=(16,12), alpha= 0.6, diagonal='kde')
#scatter_matrix(df)
plt.show()

# %% [markdown]
# Check if any of the crime rates highly correlated with heatmap

# %%
plt.figure(figsize=(10, 8))
fig = sns.heatmap(df.corr())
plt.xticks(rotation = 'vertical')
fig.get_figure().savefig('heatmap.jpg')

# %% [markdown]
# histogram for each of the seven crimes to visualize their distributions

# %%
f = plt.figure()
f.add_subplot(2,2,1)

# %%
fig = plt.figure(figsize=(10,6))
for i, crime in enumerate(df.columns[1:7]):
    fig.add_subplot(2, 3, i+1) 
    hist = df[crime].hist(bins = 10)
    hist.set_title(crime)
plt.savefig('hist.png')

# %%
for crime in df.columns[1:]:
    f = plt.figure()
    hist = df[crime].plot(kind='kde')
    hist.set_title(crime)

# %%
plt.figure(figsize=(10,8))
df.boxplot(figsize=(10,8), return_type= 'axes') #column= list(df.columns.values), 
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df)
plt.ylabel('number of reported crimes (per 100,000 population)')
plt.savefig('boxplot.jpg')

# %%
plt.figure(figsize=(10,8))
sns.violinplot(df, scale='count', inner='quartile')
plt.savefig('violin_plot.png')

# %%
plt.figure(figsize=(10,8))
sns.violinplot(df[df.columns[1:3]], scale='count', inner='quartile')

# %% [markdown]
# ## Explanatory Data Visualization

# %%
df2=df.copy()
df2.set_index(df2.State, inplace=True)
df2=df2.drop('State',axis =1)
df2.head()
# Out:
#             Murder  Rape  Robbery  Aggravated Assault  Burglary  \
# State
# Alabama        8.2  34.3    141.4               247.8     953.8
# Alaska         4.8  81.1     80.9               465.1     622.5
# Arizona        7.5  33.8    144.4               327.4     948.4
# Arkansas       6.7  42.9     91.1               386.8    1084.6
# California     6.9  26.0    176.1               317.3     693.3
#
#             Larceny Theft  Motor Vehicle Theft
# State
# Alabama            2650.0                288.3
# Alaska             2599.1                391.0
# Arizona            2965.2                924.4
# Arkansas           2711.2                262.1
# California         1916.5                712.8

# %%
df2.plot(kind='barh', figsize=(14,10), stacked=True)

# %% [markdown]
# Create a stacked bar chart (with hover tooltips) to convey the total crime rate of each state without hiding the individual breakdown of crime type

# %%
def sum_crime(df):
    return sum(df[1:])
df['total'] = df.apply(sum_crime, axis=1)
sorted_df = df.sort_values('total', ascending=False)
# Out:
# /Users/weiansheng/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
from bokeh.charts import Bar, output_file, show
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.charts.utils import df_from_json

# from bokeh.models import *



bar = Bar(sorted_df,
          values=blend('Murder', 'Rape', 'Robbery', 'Aggravated Assault', 'Burglary',
                       'Larceny Theft', 'Motor Vehicle Theft', name='Crime', labels_name='crime'),
          label=cat(columns='State', sort=False),
          stack=cat(columns='crime', sort=False),
          
          legend='top_right',
          title="Crime per state", 
          width=1000, height=500,
          tooltips=[('crime', '@crime'), ('state', '@State')]
         )


#output_file("stacked_bar.html", title="stacked_bar.py example")

show(bar)

# %%
from IPython.display import Image
Image("images/crime_stacked_plot.png")
# ![](images/crime_stacked_plot.png)

# %%
def norm_crime(df):
    return df[1:] / df['total']
normed_df = sorted_df.apply(norm_crime, axis=1)

normed_df['State']=sorted_df['State']
normed_df.head()
# Out:
#       Murder      Rape   Robbery  Aggravated Assault  Burglary  Larceny Theft  \
# 8   0.005704  0.004866  0.108300            0.116228  0.104691       0.434248
# 2   0.001402  0.006316  0.026985            0.061184  0.177235       0.554129
# 47  0.000630  0.008532  0.017580            0.039282  0.183184       0.601164
# 40  0.001451  0.008333  0.025900            0.113521  0.196240       0.579190
# 11  0.000376  0.005329  0.015551            0.029280  0.152126       0.655414
#
#     Motor Vehicle Theft  total                 State
# 8              0.225962    1.0  District of Columbia
# 2              0.172750    1.0               Arizona
# 47             0.149628    1.0            Washington
# 40             0.075367    1.0        South Carolina
# 11             0.141923    1.0                Hawaii

# %%
def plot(df):
    bar = Bar(df,
          values=blend('Murder', 'Rape', 'Robbery', 'Aggravated Assault', 'Burglary',
                       'Larceny Theft', 'Motor Vehicle Theft', name='Crime', labels_name='crime'),
          label=cat(columns='State', sort=False),
          stack=cat(columns='crime', sort=False),
          
          legend='top_right',
          title="Crime per state", 
          width=1000, height=500,
          tooltips=[('crime', '@crime'), ('state', '@State')]
         )
    show(bar)

plot(normed_df)
#plot(sorted_df)

# %%
Image("images/normed_stacked_barchart.png")

# %% [markdown]
# map, create a basic map of us states excluding HI and AK

# %%
from bokeh.sampledata import us_states
from bokeh.plotting import *

us_states = us_states.data.copy()

del us_states["HI"]
del us_states["AK"]

state_xs = [us_states[code]["lons"] for code in us_states]
state_ys = [us_states[code]["lats"] for code in us_states]

p = figure(title="State Crime Rates", toolbar_location="left",
plot_width=1100, plot_height=700)

p.patches(state_xs, state_ys, fill_alpha=0.0,
line_color="#884444", line_width=2)

show(p)

# %%
df2['Larceny Theft rate'] = df2['Larceny Theft']/df2.sum(axis=1)

# %%
df3 = df2[(df2.index!='Alaska') & (df2.index!='Hawaii')]

# %%
df3.head()
# Out:
#             Murder  Rape  Robbery  Aggravated Assault  Burglary  \
# State
# Alabama        8.2  34.3    141.4               247.8     953.8
# Arizona        7.5  33.8    144.4               327.4     948.4
# Arkansas       6.7  42.9     91.1               386.8    1084.6
# California     6.9  26.0    176.1               317.3     693.3
# Colorado       3.7  43.4     84.6               264.7     744.8
#
#             Larceny Theft  Motor Vehicle Theft  Larceny Theft rate
# State
# Alabama            2650.0                288.3            0.612887
# Arizona            2965.2                924.4            0.554129
# Arkansas           2711.2                262.1            0.591268
# California         1916.5                712.8            0.497934
# Colorado           2735.2                559.5            0.616605

# %%
us_states.values()[0]['name']
# Out:
# 'Washington'

# %%
df3.ix[states[0]]
# Out:
# Murder                    3.300000
# Rape                     44.700000
# Robbery                  92.100000
# Aggravated Assault      205.800000
# Burglary                959.700000
# Larceny Theft          3149.500000
# Motor Vehicle Theft     783.900000
# Larceny Theft rate        0.601164
# Name: Washington, dtype: float64

# %% [markdown]
# Draw the state borders
#
# Figure out the correct color mapping from (rate => hexadecimal value)
#
# Put it all together with original source data
#
# Add hover tooltip interaction

# %%
states=[a['name'] for a in us_states.values()]
rates = [df2.ix[state_name]['Larceny Theft'] for state_name in states]

# %%
cm = plt.get_cmap('YlOrRd')
c_map = plt.cm.ScalarMappable(cmap=cm)
c_map.set_clim(df2['Larceny Theft'].min(), df2['Larceny Theft'].max())

# %%
state_colors0=[c_map.to_rgba(rate) for rate in rates]
state_colors = [ (c[0] * 255, c[1] * 255, c[2] * 255) for c in state_colors0 ]
state_hex = [  ('#%02x%02x%02x' % c) for c in state_colors]

# %%
# rates0=list(df3['Larceny Theft'].values)
# states0 = list(df3.index.values)

# %%
rates
# Out:
# [3149.5,
#  2144.0,
#  2694.9000000000001,
#  1992.8,
#  1794.0,
#  2658.3000000000002,
#  2533.9000000000001,
#  1377.3,
#  1568.4000000000001,
#  2639.9000000000001,
#  2961.6999999999998,
#  2494.5,
#  2546.1999999999998,
#  1500.3,
#  2574.3000000000002,
#  2828.0999999999999,
#  1569.5999999999999,
#  1729.0999999999999,
#  1816.0,
#  2153.9000000000001,
#  2035.0,
#  2735.1999999999998,
#  2650.0,
#  2711.1999999999998,
#  1686.0999999999999,
#  2164.8000000000002,
#  2751.0999999999999,
#  2412.0,
#  2042.7,
#  1527.4000000000001,
#  2965.1999999999998,
#  1916.5,
#  1931.7,
#  1824.0999999999999,
#  1832.5999999999999,
#  2294.3000000000002,
#  2644.1999999999998,
#  2429.0,
#  2918.8000000000002,
#  2746.1999999999998,
#  2226.9000000000001,
#  1917.8,
#  2758.0999999999999,
#  2543.0,
#  2083.9000000000001,
#  2954.0999999999999,
#  1685.8,
#  3112.1999999999998,
#  1343.7]

# %% [markdown]
# draw the final map

# %%
from bokeh.sampledata import us_states
from bokeh.models import HoverTool
from collections import OrderedDict

us_states = us_states.data.copy()

del us_states["HI"]
del us_states["AK"]

state_xs = [us_states[code]["lons"] for code in us_states]
state_ys = [us_states[code]["lats"] for code in us_states]

TOOLS="pan,wheel_zoom,box_zoom,reset,hover,save"

source = ColumnDataSource(
    data=dict(
        rate=rates,
        state=states
    )
)

p = figure(title="State Crime Rates", toolbar_location="left",
    plot_width=1100, plot_height=700, tools=TOOLS)

p.patches(state_xs, state_ys, fill_color=state_hex,
    line_color="#884444", line_width=2, source=source)


hover = p.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([
    ("State", "@state"),
    ('rate', '@rate'),
    ("(x,y)", "($x, $y)"),
])

show(p)

# %%
Image("images/map_crime0.png")

# %%
ColumnDataSource
# Out:
# bokeh.models.sources.ColumnDataSource

# %%
state_colors
# Out:
# [(166.27451509237289, 0.0, 38.000001534819603),
#  (253.73725497722626, 168.27843654155731, 71.796080753207207),
#  (238.96078526973724, 50.878432966768742, 34.698039956390858),
#  (254.00000005960464, 192.22353315353396, 91.317649215459824),
#  (254.18039220571518, 220.60784518718719, 125.57647207379341),
#  (242.88235366344452, 59.035296119749546, 36.894118554890156),
#  (252.13725507259369, 86.647062301635728, 44.4705893844366),
#  (255.0, 252.74117660522461, 198.47843474149704),
#  (255.0, 238.62353038787842, 163.96863287687302),
#  (245.23529469966888, 63.929414011538029, 38.211765713989735),
#  (204.64706182479858, 10.705882497131823, 33.882353939116001),
#  (252.32549035549164, 98.505886554718018, 47.858824476599693),
#  (252.10588252544403, 84.670591592788696, 43.90588353574276),
#  (255.0, 243.70588302612305, 176.39216154813766),
#  (251.50980412960052, 76.980395056307316, 41.725491471588612),
#  (224.91372728347778, 24.572549350559711, 28.549019910395145),
#  (255.0, 238.62353038787842, 163.96863287687302),
#  (254.43137258291245, 225.62745273113251, 136.1176498234272),
#  (254.0862745642662, 218.7254923582077, 121.62353041768075),
#  (253.7058824300766, 167.11765229701996, 71.294119879603386),
#  (254.00000005960464, 184.88235712051392, 83.411767333745971),
#  (235.03921687602997, 42.72156981378793, 32.50196135789156),
#  (243.66666734218597, 60.666668750345707, 37.333334274590015),
#  (237.39215791225433, 47.61568770557642, 33.819608516991138),
#  (254.61960786581039, 229.39215838909149, 144.02353313565254),
#  (253.67450988292694, 165.9568680524826, 70.792159005999565),
#  (233.47058951854706, 39.458824552595608, 31.62352991849184),
#  (252.63921582698822, 118.27059364318848, 53.50588296353817),
#  (254.00000005960464, 183.65882778167725, 82.094120353460312),
#  (255.0, 242.0117654800415, 172.25098532438278),
#  (203.45490503311157, 9.8901962116360664, 34.196079470217228),
#  (254.00000005960464, 204.45882654190066, 104.49411901831628),
#  (254.00000005960464, 202.01176786422729, 101.85882505774498),
#  (254.05490201711655, 218.09804141521454, 120.30588319897652),
#  (254.02352946996689, 217.47059047222137, 118.98823598027229),
#  (253.14117658138275, 146.22353589534762, 62.258824154734612),
#  (244.45098102092743, 62.298041380941868, 37.772549994289875),
#  (252.5764707326889, 114.3176522254944, 52.376471266150475),
#  (210.60784578323364, 14.784313924610615, 32.313726283609867),
#  (234.25490319728851, 41.090197183191769, 32.0627456381917),
#  (253.39215695858002, 155.50980985164642, 66.274511143565178),
#  (254.00000005960464, 204.45882654190066, 104.49411901831628),
#  (232.6862758398056, 37.827451921999447, 31.184314198791977),
#  (252.10588252544403, 84.670591592788696, 43.90588353574276),
#  (253.98823535442352, 177.56471049785614, 75.811767742037773),
#  (205.83921861648557, 11.521568782627583, 33.568628408014774),
#  (254.61960786581039, 229.39215838909149, 144.02353313565254),
#  (175.84314197301865, 0.0, 38.000001534819603),
#  (255.0, 255.0, 204.00000303983688)]

# %%
df3['Larceny Theft'].sort_values()
# Out:
# State
# South Dakota            1343.7
# New Hampshire           1377.3
# North Dakota            1500.3
# Massachusetts           1527.4
# New Jersey              1568.4
# New York                1569.6
# Kentucky                1685.8
# Vermont                 1686.1
# Pennsylvania            1729.1
# West Virginia           1794.0
# Rhode Island            1816.0
# Connecticut             1824.1
# Maine                   1832.6
# California              1916.5
# Michigan                1917.8
# Idaho                   1931.7
# Wisconsin               1992.8
# Virginia                2035.0
# Iowa                    2042.7
# Mississippi             2083.9
# Delaware                2144.0
# Nevada                  2153.9
# Illinois                2164.8
# Minnesota               2226.9
# Maryland                2294.3
# Indiana                 2412.0
# Ohio                    2429.0
# Louisiana               2494.5
# Wyoming                 2533.9
# Montana                 2543.0
# North Carolina          2546.2
# Nebraska                2574.3
# New Mexico              2639.9
# Oklahoma                2644.2
# Alabama                 2650.0
# Florida                 2658.3
# District of Columbia    2694.9
# Arkansas                2711.2
# Colorado                2735.2
# Missouri                2746.2
# Georgia                 2751.1
# Kansas                  2758.1
# Tennessee               2828.1
# Utah                    2918.8
# South Carolina          2954.1
# Texas                   2961.7
# Arizona                 2965.2
# Oregon                  3112.2
# Washington              3149.5
# Name: Larceny Theft, dtype: float64
